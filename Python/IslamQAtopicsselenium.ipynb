# %%
from selenium import webdriver
import time
    
driver = webdriver.Chrome()
driver.get('https://islamqa.info/en')

for i in range (1,1001):
    link = f'https://islamqa.info/en/categories/topics/{i}'
    driver.get(link)
    time.sleep(0.5)
    print(f'{i}. {driver.title}')
# Out:
# 1. Rulings on Jihaad - Islam Question & Answer
# 2. Enjoining what is good and forbidding what is evil - Islam Question & Answer
# 3. Basic Tenets of Faith - Islam Question & Answer
# 4. Belief - Islam Question & Answer
# 5. Belief in Allaah - Islam Question & Answer
# 6. Belief in the Angels - Islam Question & Answer
# 7. Belief in Divinely-revealed Books - Islam Question & Answer
# 8. Belief in the Messengers - Islam Question & Answer
# 9. Belief in the Last Day and the Signs of the Hour - Islam Question & Answer
# 10. Torment and Blessing in the Grave - Islam Question & Answer
# 11. Paradise and Hell - Islam Question & Answer
# 12. The Signs of the Hour - Islam Question & Answer
# 13. Belief in the Divine Will and Decree - Islam Question & Answer
# 14. Belief in the Jinn, witchcraft and the evil eye - Islam Question & Answer
# 15. Tawheed (Divine Unity) - Islam Question & Answer
# 16. (Unity of) Divine Lordship - Islam Question & Answer
# ...
